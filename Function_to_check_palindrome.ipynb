# %% [markdown]
# <a href="https://colab.research.google.com/github/Mithilesh1262/Davis_lab_work/blob/main/Function_to_check_palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to check palindrome
def check_palindrome(value):
    value = str(value)  # Convert input to string
    reversed_value = ""

    # Use a for loop to reverse the string
    for char in value:
        reversed_value = char + reversed_value

    # Check if original and reversed are the same
    if value == reversed_value:
        print(value, "is a Palindrome")
    else:
        print(value, "is NOT a Palindrome")

# Input from user
user_input = input("Enter a number or string: ")
check_palindrome(user_input)
# Out:
# Enter a number or string: 3
# 3 is a Palindrome
